# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt

# %%
database_normalizada = pd.read_csv('resultado/dados_curitiba.csv', sep=";")
database_sem_normalizacao = pd.read_csv('resultado/dados_curitiba_sem_equalizacao.csv', sep=";")

# %%
num_img = database_normalizada.Imagem.values.tolist()
diferenca_normalizado = database_normalizada.SIFT_SIFT_Diferenca.values.tolist()
database_nao_normalizacao = database_sem_normalizacao.SIFT_SIFT_Diferenca.values.tolist()

num_img = list(map(int, num_img))

# %%
database = {
    'normalizado': diferenca_normalizado,
    'não normalizado': database_nao_normalizacao
}

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.stackplot(num_img, database.values(),
             labels=database.keys(), alpha=0.8)
ax.legend(loc='upper left')
ax.set_title('TÍTULO')
ax.set_xlabel('Imagens')
ax.set_ylabel('Diferença')

plt.show()

# %%
database_normalizada
# Out:
#     Imagem  SIFT_SIFT_Inliers  SIFT_SIFT_Outliers  SIFT_SIFT_Diferenca  \
# 0        1                 24                  40            21.796325
# 1        2                 47                  34            27.514162
# 2        3                 69                  51            23.891861
# 3        4                 20                  49            33.136498
# 4        5                 51                  54            26.520584
# ..     ...                ...                 ...                  ...
# 95      96                 28                  48            28.215719
# 96      97                 61                  59            26.228219
# 97      98                 83                  57            26.984220
# 98      99                 45                  52            39.373980
# 99     100                171                 115            29.767000
#
#    SIFT_SIFT_Tempo  SIFT_SIFT_45_Inliers  SIFT_SIFT_45_Outliers  \
# 0   0:00:03.469325                    19                     23
# 1   0:00:08.168090                    49                     37
# 2   0:00:08.255228                    92                     29
# 3   0:00:05.495926                    27                     93
# 4   0:00:05.267142                    80                     43
# ..             ...                   ...                    ...
# 95  0:00:05.375706                    39                     40
# 96  0:00:08.122035                    61                     48
# 97  0:00:07.750853                    93                     55
# 98  0:00:22.212418                    61                     56
# 99  0:00:12.476572                   255                    116
#
#     SIFT_SIFT_45_Diferenca SIFT_SIFT_45_Tempo  ORB_ORB_Inliers  ...  \
# 0                17.933697     0:00:02.387018                7  ...
# 1                21.527085     0:00:05.099386               10  ...
# 2                19.241227     0:00:05.584593               28  ...
# 3                27.793363     0:00:04.531558                9  ...
# 4                21.081509     0:00:04.261025                8  ...
# ..                     ...                ...              ...  ...
# 95               21.628219     0:00:04.051886                9  ...
# 96               20.726606     0:00:05.583448                9  ...
# 97               21.490479     0:00:05.210834               16  ...
# 98               29.663656     0:00:14.486792               14  ...
# 99               22.703796     0:00:08.649863               21  ...
#
#     FAST_BRIEF_45_Tempo  FAST_SIFT_Inliers FAST_SIFT_Outliers  \
# 0        0:00:00.996638                 24                 40
# 1        0:00:01.809322                 47                 34
# 2        0:00:01.755263                 69                 51
# 3        0:00:01.550672                 20                 49
# 4        0:00:01.483075                 51                 54
# ..                  ...                ...                ...
# 95       0:00:01.679264                 28                 48
# 96       0:00:01.228069                 61                 59
# 97       0:00:01.491948                 83                 57
# 98       0:00:04.388950                 45                 52
# 99       0:00:02.387664                171                115
#
#     FAST_SIFT_Diferenca  FAST_SIFT_Tempo  FAST_SIFT_45_Inliers  \
# 0             21.796325   0:00:03.550631                    19
# 1             27.514162   0:00:08.163101                    49
# 2             23.891861   0:00:08.034569                    92
# 3             33.136498   0:00:05.484835                    27
# 4             26.520584   0:00:05.317749                    80
# ..                  ...              ...                   ...
# 95            28.215719   0:00:05.474596                    39
# 96            26.228219   0:00:08.115738                    61
# 97            26.984220   0:00:07.877193                    93
# 98            39.373980   0:00:22.531191                    61
# 99            29.767000   0:00:12.612643                   255
#
#    FAST_SIFT_45_Outliers  FAST_SIFT_45_Diferenca  FAST_SIFT_45_Tempo  \
# 0                     23               17.933697      0:00:02.402271
# 1                     37               21.527085      0:00:05.116508
# 2                     29               19.241227      0:00:05.423032
# 3                     93               27.793363      0:00:04.545809
# 4                     43               21.081509      0:00:04.284277
# ..                   ...                     ...                 ...
# 95                    40               21.628219      0:00:04.089581
# 96                    48               20.726606      0:00:05.925749
# 97                    55               21.490479      0:00:05.218518
# 98                    56               29.663656      0:00:14.522630
# 99                   116               22.703796      0:00:08.730130
#
#     Unnamed: 41
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 95          NaN
# 96          NaN
# 97          NaN
# 98          NaN
# 99          NaN
#
# [100 rows x 42 columns]

# %%
sift_sift_inliers = database_normalizada.SIFT_SIFT_Inliers.values.tolist()
orb_orb_inliers = database_normalizada.ORB_ORB_Inliers.values.tolist()
akaze_akaze_inliers = database_normalizada.AKAZE_AKAZE_Inliers.values.tolist()
fast_brief_inliers  = database_normalizada.FAST_BRIEF_Inliers.values.tolist()
fast_sift_inliers  = database_normalizada.FAST_SIFT_Inliers.values.tolist()

sift_sift_tempo = database_normalizada.SIFT_SIFT_Tempo.values.tolist()
orb_orb_tempo = database_normalizada.ORB_ORB_Tempo.values.tolist()
akaze_akaze_tempo = database_normalizada.AKAZE_AKAZE_Tempo.values.tolist()
fast_brief_tempo  = database_normalizada.FAST_BRIEF_Tempo.values.tolist()
fast_sift_tempo  = database_normalizada.FAST_SIFT_Tempo.values.tolist()

# %%
sift_sift_inliers
# Out:
# [24,
#  47,
#  69,
#  20,
#  51,
#  12,
#  7,
#  13,
#  37,
#  12,
#  18,
#  34,
#  11,
#  243,
#  655,
#  732,
#  363,
#  479,
#  100,
#  285,
#  44,
#  210,
#  169,
#  445,
#  67,
#  112,
#  41,
#  72,
#  82,
#  119,
#  60,
#  120,
#  97,
#  40,
#  78,
#  72,
#  149,
#  149,
#  43,
#  54,
#  54,
#  77,
#  71,
#  38,
#  22,
#  36,
#  67,
#  48,
#  37,
#  46,
#  22,
#  28,
#  65,
#  36,
#  45,
#  37,
#  14,
#  23,
#  8,
#  26,
#  27,
#  25,
#  34,
#  34,
#  45,
#  50,
#  64,
#  61,
#  43,
#  30,
#  46,
#  27,
#  46,
#  26,
#  31,
#  38,
#  44,
#  29,
#  16,
#  22,
#  19,
#  32,
#  40,
#  31,
#  35,
#  67,
#  29,
#  40,
#  16,
#  23,
#  29,
#  25,
#  18,
#  27,
#  36,
#  28,
#  61,
#  83,
#  45,
#  171]

# %%
plt.plot(fast_sift_inliers , color='green', label='fast sift')
plt.plot(sift_sift_inliers, color='red', label='sift')
plt.plot(orb_orb_inliers, color='blue', label='orb')
plt.plot(akaze_akaze_inliers, color='orange', label='akaze')
plt.plot(fast_brief_inliers , color='purple', label='fast brief')
plt.xlabel('Inliers')
plt.ylabel('Valores')
plt.legend()
plt.show()

# %%
def retorna_acertos_tempo(lista_inliers, lista_tempo):
    acertos = 0
    tempo_total = datetime.timedelta()
    for inlier, tempo in zip(lista_inliers, lista_tempo):
        tempo_obj = datetime.datetime.strptime(tempo, "%H:%M:%S.%f").time()
        delta = datetime.timedelta(
                hours=tempo_obj.hour,
                minutes=tempo_obj.minute,
                seconds=tempo_obj.second,
                microseconds=tempo_obj.microsecond
            )
        tempo_total += delta

        if inlier >= 20:
            acertos += 1
    return acertos, tempo_total

sift_sift_inliers_acertos, sift_sift_inliers_tempo = \
    retorna_acertos_tempo(sift_sift_inliers, sift_sift_tempo)

orb_orb_inliers_acertos, orb_orb_inliers_tempo = \
    retorna_acertos_tempo(orb_orb_inliers, orb_orb_tempo)

akaze_akaze_inliers_acertos, akaze_akaze_inliers_tempo = \
    retorna_acertos_tempo(akaze_akaze_inliers, akaze_akaze_tempo)

fast_brief_inliers_acertos, fast_brief_inliers_tempo = \
    retorna_acertos_tempo(fast_brief_inliers, fast_brief_tempo)

fast_sift_inliers_acertos, fast_sift_inliers_tempo  = \
    retorna_acertos_tempo(fast_sift_inliers, fast_sift_tempo)

# %%
print(f"sift = {sift_sift_inliers_acertos}\t\ttempo: {sift_sift_inliers_tempo.seconds}s \n"
      f"orb = {orb_orb_inliers_acertos}\t\ttempo: {orb_orb_inliers_tempo.seconds}s\n"
      f"akaze = {akaze_akaze_inliers_acertos}\t\ttempo: {akaze_akaze_inliers_tempo.seconds}s\n"
      f"fast brief = {fast_brief_inliers_acertos}\t\ttempo: {fast_brief_inliers_tempo.seconds}s\n"
      f"fast sift = {fast_sift_inliers_acertos}\t\ttempo:{fast_sift_inliers_tempo.seconds}s")
# Out:
# sift = 88		tempo: 6969s
# orb = 16		tempo: 6s
# akaze = 55		tempo: 2967s
# fast brief = 99		tempo: 2292s
# fast sift = 88		tempo:5023s
