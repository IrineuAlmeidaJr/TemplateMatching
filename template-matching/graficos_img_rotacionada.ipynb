# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt

# %%
database_normalizada = pd.read_csv('resultado/dados_curitiba.csv', sep=";")

# %%
database_normalizada
# Out:
#     Imagem  SIFT_SIFT_Inliers  SIFT_SIFT_Outliers  SIFT_SIFT_Diferenca  \
# 0        1                 28                  50            45.297912
# 1        2                 51                  36            37.240598
# 2        3                 73                  55            35.459698
# 3        4                 24                  60            41.761299
# 4        5                 67                  48            31.469953
# ..     ...                ...                 ...                  ...
# 95      96                 27                  64            35.851601
# 96      97                 69                  76            48.514841
# 97      98                101                  61            40.677403
# 98      99                 50                  50            40.454670
# 99     100                193                  95            39.323596
#
#    SIFT_SIFT_Tempo  SIFT_SIFT_45_Inliers  SIFT_SIFT_45_Outliers  \
# 0   0:00:05.785902                    29                     40
# 1   0:00:10.474085                    35                     37
# 2   0:00:10.696765                    55                     45
# 3   0:00:07.373145                    19                     56
# 4   0:00:06.864706                    59                     47
# ..             ...                   ...                    ...
# 95  0:00:07.684104                    27                     43
# 96  0:00:11.225247                    59                     71
# 97  0:00:10.807349                    78                     46
# 98  0:00:26.613119                    42                     44
# 99  0:00:16.143738                   192                     93
#
#     SIFT_SIFT_45_Diferenca SIFT_SIFT_45_Tempo  ORB_ORB_Inliers  ...  \
# 0                36.589374     0:00:04.492378                8  ...
# 1                28.187085     0:00:08.639821                9  ...
# 2                26.655969     0:00:08.680069               33  ...
# 3                33.691975     0:00:06.057736                9  ...
# 4                24.132752     0:00:06.158259                8  ...
# ..                     ...                ...              ...  ...
# 95               27.150464     0:00:06.795608               14  ...
# 96               37.758030     0:00:09.506244                7  ...
# 97               30.414045     0:00:09.238919               12  ...
# 98               32.140962     0:00:21.658444               13  ...
# 99               29.382660     0:00:13.456597               22  ...
#
#     FAST_BRIEF_45_Tempo  FAST_SIFT_Inliers FAST_SIFT_Outliers  \
# 0        0:00:02.828335                 28                 50
# 1        0:00:04.173633                 51                 36
# 2        0:00:03.860941                 73                 55
# 3        0:00:03.256089                 24                 60
# 4        0:00:02.976087                 67                 48
# ..                  ...                ...                ...
# 95       0:00:04.748362                 27                 64
# 96       0:00:03.790754                 69                 76
# 97       0:00:04.196955                101                 61
# 98       0:00:10.033659                 50                 50
# 99       0:00:05.544875                193                 95
#
#     FAST_SIFT_Diferenca  FAST_SIFT_Tempo  FAST_SIFT_45_Inliers  \
# 0             45.297912   0:00:06.056114                    29
# 1             37.240598   0:00:11.086166                    35
# 2             35.459698   0:00:11.261405                    55
# 3             41.761299   0:00:07.678815                    19
# 4             31.469953   0:00:07.063784                    59
# ..                  ...              ...                   ...
# 95            35.851601   0:00:07.682981                    27
# 96            48.514841   0:00:11.523930                    59
# 97            40.677403   0:00:10.955774                    78
# 98            40.454670   0:00:26.551720                    42
# 99            39.323596   0:00:16.230099                   192
#
#    FAST_SIFT_45_Outliers  FAST_SIFT_45_Diferenca  FAST_SIFT_45_Tempo  \
# 0                     40               36.589374      0:00:04.646073
# 1                     37               28.187085      0:00:08.939568
# 2                     45               26.655969      0:00:08.905048
# 3                     56               33.691975      0:00:06.208950
# 4                     47               24.132752      0:00:06.382937
# ..                   ...                     ...                 ...
# 95                    43               27.150464      0:00:06.763877
# 96                    71               37.758030      0:00:09.624587
# 97                    46               30.414045      0:00:09.232296
# 98                    44               32.140962      0:00:21.662454
# 99                    93               29.382660      0:00:13.567449
#
#     Unnamed: 41
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 95          NaN
# 96          NaN
# 97          NaN
# 98          NaN
# 99          NaN
#
# [100 rows x 42 columns]

# %%
sift_sift_inliers = database_normalizada.SIFT_SIFT_45_Inliers.values.tolist()
orb_orb_inliers = database_normalizada.ORB_ORB_45_Inliers.values.tolist()
akaze_akaze_inliers = database_normalizada.AKAZE_AKAZE_45_Inliers.values.tolist()
fast_brief_inliers  = database_normalizada.FAST_BRIEF_45_Inliers.values.tolist()
fast_sift_inliers  = database_normalizada.FAST_SIFT_45_Inliers.values.tolist()

sift_sift_tempo = database_normalizada.SIFT_SIFT_45_Tempo.values.tolist()
orb_orb_tempo = database_normalizada.ORB_ORB_45_Tempo.values.tolist()
akaze_akaze_tempo = database_normalizada.AKAZE_AKAZE_45_Tempo.values.tolist()
fast_brief_tempo  = database_normalizada.FAST_BRIEF_45_Tempo.values.tolist()
fast_sift_tempo  = database_normalizada.FAST_SIFT_45_Tempo.values.tolist()

# %%
sift_sift_inliers
# Out:
# [29,
#  35,
#  55,
#  19,
#  59,
#  10,
#  5,
#  8,
#  17,
#  7,
#  18,
#  33,
#  10,
#  161,
#  461,
#  525,
#  247,
#  462,
#  44,
#  226,
#  36,
#  182,
#  137,
#  425,
#  48,
#  81,
#  34,
#  55,
#  73,
#  82,
#  55,
#  108,
#  109,
#  33,
#  74,
#  47,
#  99,
#  97,
#  32,
#  45,
#  49,
#  84,
#  79,
#  33,
#  21,
#  27,
#  67,
#  32,
#  31,
#  36,
#  9,
#  25,
#  48,
#  25,
#  30,
#  42,
#  11,
#  9,
#  7,
#  31,
#  23,
#  19,
#  18,
#  19,
#  37,
#  32,
#  38,
#  51,
#  52,
#  14,
#  45,
#  22,
#  30,
#  25,
#  28,
#  23,
#  32,
#  27,
#  18,
#  19,
#  17,
#  43,
#  25,
#  20,
#  26,
#  46,
#  26,
#  41,
#  6,
#  19,
#  23,
#  20,
#  19,
#  23,
#  48,
#  27,
#  59,
#  78,
#  42,
#  192]

# %%
plt.plot(fast_sift_inliers , color='green', label='fast sift')
plt.plot(sift_sift_inliers, color='red', label='sift')
plt.plot(orb_orb_inliers, color='blue', label='orb')
plt.plot(akaze_akaze_inliers, color='orange', label='akaze')
plt.plot(fast_brief_inliers , color='purple', label='fast brief')
plt.xlabel('Inliers')
plt.ylabel('Valores')
plt.legend()
plt.show()

# %%
def retorna_acertos_tempo(lista_inliers, lista_tempo):
    acertos = 0
    tempo_total = datetime.timedelta()
    for inlier, tempo in zip(lista_inliers, lista_tempo):
        tempo_obj = datetime.datetime.strptime(tempo, "%H:%M:%S.%f").time()
        delta = datetime.timedelta(
                hours=tempo_obj.hour,
                minutes=tempo_obj.minute,
                seconds=tempo_obj.second,
                microseconds=tempo_obj.microsecond
            )
        tempo_total += delta

        if inlier >= 20:
            acertos += 1
    return acertos, tempo_total

sift_sift_inliers_acertos, sift_sift_inliers_tempo = \
    retorna_acertos_tempo(sift_sift_inliers, sift_sift_tempo)

orb_orb_inliers_acertos, orb_orb_inliers_tempo = \
    retorna_acertos_tempo(orb_orb_inliers, orb_orb_tempo)

akaze_akaze_inliers_acertos, akaze_akaze_inliers_tempo = \
    retorna_acertos_tempo(akaze_akaze_inliers, akaze_akaze_tempo)

fast_brief_inliers_acertos, fast_brief_inliers_tempo = \
    retorna_acertos_tempo(fast_brief_inliers, fast_brief_tempo)

fast_sift_inliers_acertos, fast_sift_inliers_tempo  = \
    retorna_acertos_tempo(fast_sift_inliers, fast_sift_tempo)

# %%
def minutos_segundo(tempo):
    minutos = (int)(tempo / 60)
    segundos = tempo % 60
    return f"{minutos}m {segundos}s"

# %%
print(f"sift = {sift_sift_inliers_acertos}\t\ttempo: {minutos_segundo(sift_sift_inliers_tempo.seconds)} \n"
      f"orb = {orb_orb_inliers_acertos}\t\ttempo: {minutos_segundo(orb_orb_inliers_tempo.seconds)}\n"
      f"akaze = {akaze_akaze_inliers_acertos}\t\ttempo: {minutos_segundo(akaze_akaze_inliers_tempo.seconds)}\n"
      f"fast brief = {fast_brief_inliers_acertos}\t\ttempo: {minutos_segundo(fast_brief_inliers_tempo.seconds)}\n"
      f"fast sift = {fast_sift_inliers_acertos}\t\ttempo:{minutos_segundo(fast_sift_inliers_tempo.seconds)}")
# Out:
# sift = 78		tempo: 15m 6s
# orb = 11		tempo: 0m 6s
# akaze = 49		tempo: 1m 28s
# fast brief = 0		tempo: 6m 37s
# fast sift = 78		tempo:15m 11s
